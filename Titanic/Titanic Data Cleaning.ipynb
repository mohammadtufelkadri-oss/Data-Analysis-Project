# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'D:\TUFEL\Data scientist pro\Machine Learinng\Projects\Logistic Regression (Titanic)\documents (2)\ML Project - Logistic Regression Titanic Survival U16955478860.txt')

# %% [markdown]
# # 1.print all the column names

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
pd.DataFrame(df.columns)
# Out:
#               0
# 0   PassengerId
# 1      Survived
# 2        Pclass
# 3          Name
# 4           Sex
# 5           Age
# 6         SibSp
# 7         Parch
# 8        Ticket
# 9          Fare
# 10        Cabin
# 11     Embarked

# %% [markdown]
# # 3) describe the data

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # 4) check the null value

# %%
df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %% [markdown]
# # 5) if there are Null values, Handle these

# %% [markdown]
# ## Age

# %% [raw]
# We have null values in age column so we will replace them by median

# %%
df['Age'].fillna(df['Age'].median(),inplace=True)

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# ## Cabin

# %%
df['Cabin'].isnull()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
round(df['Cabin'].isnull().sum()/len(df)*100)
# Out:
# 77

# %% [raw]
# Here in Cabin column we have null Values more than 70% so we will drop that column

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Embarked
# 0      0  A/5 21171  7.25        S

# %% [markdown]
# # Embarked

# %%
df['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %% [raw]
# So, here we can se "Embarked" is a categorical table so first we will find mode

# %%
df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %% [raw]
# We will fill this column with 'S'

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0],inplace=True)

# %%
df['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %% [markdown]
# ## Now we will Check for null values

# %%
df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Embarked       False
# dtype: bool

# %%
df['Survived'].unique()
# Out:
# array([0, 1])

# %%
a={0:'Not Survived',
   1:'Survived'}

# %%
df['Survived'].replace(a,inplace=True)

# %%
df['Survived']
# Out:
# 0      Not Survived
# 1          Survived
# 2          Survived
# 3          Survived
# 4      Not Survived
#            ...
# 886    Not Survived
# 887        Survived
# 888    Not Survived
# 889        Survived
# 890    Not Survived
# Name: Survived, Length: 891, dtype: object

# %%
pwd
# Out:
# 'C:\\Users\\Admin\\Desktop'
