# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'D:\TUFEL\Data scientist pro\Data analysis project\Capstone Project\Car Dataset Cleaned.csv')

# %%
df.head(1)
# Out:
#   vehicle_uid           name  year  selling_price  km_driven    fuel  \
# 0  CAR_000001  Maruti 800 AC  2007          60000      70000  Petrol
#
#   seller_type transmission        owner  car_record_id  car_age  \
# 0  Individual       Manual  First Owner              1       18
#
#   price_category km_category  owner_count fuel_transmission   brand  \
# 0            Low      Medium            0     Petrol_Manual  Maruti
#
#    price_per_km  is_diesel
# 0          0.86          0

# %%
data1 = df[['vehicle_uid', 'name', 'year', 'fuel', 'seller_type', 'transmission', 'owner', 'car_age', 'brand' ]]

# %%
data2 = df[['vehicle_uid', 'selling_price', 'km_driven', 'price_category', 'km_category' ]]

# %%
data1.to_csv('Vehical_info.csv',index=False)

# %%
pwd
# Out:
# 'C:\\Users\\Admin\\Data Analyst Project'

# %%
data2.to_csv('Vehical_sales.csv',index=False)

# %%
df.isnull().sum()
# Out:
# vehicle_uid          0
# name                 0
# year                 0
# selling_price        0
# km_driven            0
# fuel                 0
# seller_type          0
# transmission         0
# owner                0
# car_record_id        0
# car_age              0
# price_category       0
# km_category          0
# owner_count          0
# fuel_transmission    0
# brand                0
# price_per_km         0
# is_diesel            0
# dtype: int64

# %%
# Should Be Deleted
# 1.Vehicle id
# 2.Car record id
# 3.Owner count
# 4.Fuel Transmission
# 5.is diesel

# %%
df.drop(['vehicle_uid','fuel_transmission','is_diesel'],axis=1)
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      60000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      60000
# 4339                     Renault KWID RXT  2016        4461000      40000
#
#         fuel seller_type transmission         owner  car_record_id  car_age  \
# ...
