# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'D:\TUFEL\Data scientist pro\Python\Projects\Car_details(U).csv')

# %%
df.head()
# Out:
#   vehicle_uid                      name  year  selling_price  km_driven  \
# 0  CAR_000001             Maruti 800 AC  2007        60000.0    70000.0
# 1  CAR_000002  Maruti Wagon R LXI Minor  2007       135000.0    50000.0
# 2  CAR_000003      Hyundai Verna 1.6 SX  2012       600000.0   100000.0
# 3  CAR_000004    Datsun RediGO T Option  2017       250000.0    46000.0
# 4  CAR_000005     Honda Amaze VX i-DTEC  2014       450000.0   141000.0
#
#      fuel seller_type transmission         owner  car_record_id  car_age  \
# 0  Petrol  Individual       Manual   First Owner              1       18
# 1     NaN  Individual       Manual   First Owner              2       18
# 2  Diesel  Individual       Manual   First Owner              3       13
# 3  Petrol  Individual       Manual   First Owner              4        8
# 4  Diesel  Individual       Manual  Second Owner              5       11
#
#   price_category km_category  owner_count fuel_transmission    brand  \
# ...

# %%
df.isnull().sum()
# Out:
# vehicle_uid            0
# name                   0
# year                   0
# selling_price        434
# km_driven            434
# fuel                 435
# seller_type            0
# transmission         434
# owner                  0
# car_record_id          0
# car_age                0
# price_category       434
# km_category          434
# owner_count          434
# fuel_transmission      0
# brand                  0
# price_per_km           0
# is_diesel              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   vehicle_uid        4340 non-null   object
#  1   name               4340 non-null   object
#  2   year               4340 non-null   int64
#  3   selling_price      3906 non-null   float64
#  4   km_driven          3906 non-null   float64
#  5   fuel               3905 non-null   object
#  6   seller_type        4340 non-null   object
#  7   transmission       3906 non-null   object
#  8   owner              4340 non-null   object
#  9   car_record_id      4340 non-null   int64
#  10  car_age            4340 non-null   int64
#  11  price_category     3906 non-null   object
#  12  km_category        3906 non-null   object
#  13  owner_count        3906 non-null   float64
#  14  fuel_transmission  4340 non-null   object
#  15  brand              4340 non-null   object
# ...

# %% [markdown]
# # •  Identify the maximum and minimum values of the selling_price column.

# %% [raw]
# Maximum

# %%
print('Max Selling Price: ',round(df['selling_price'].max()))
# Out:
# Max Selling Price:  8900000

# %% [raw]
# Minimum

# %%
print('Min Selling Price: ',round(df['selling_price'].min()))
# Out:
# Min Selling Price:  22000

# %% [markdown]
# # Calculate the average of these two values and use this average to fill all missing values in selling_price.

# %%
Max=round(df['selling_price'].max())

# %%
Min=round(df['selling_price'].min())

# %%
(8900000+22000)/2
# Out:
# 4461000.0

# %%
df['selling_price'].fillna(4461000.0,inplace=True)

# %%
df.isnull().sum()
# Out:
# vehicle_uid            0
# name                   0
# year                   0
# selling_price          0
# km_driven            434
# fuel                 435
# seller_type            0
# transmission         434
# owner                  0
# car_record_id          0
# car_age                0
# price_category       434
# km_category          434
# owner_count          434
# fuel_transmission      0
# brand                  0
# price_per_km           0
# is_diesel              0
# dtype: int64

# %% [markdown]
# # •  Handle the km_driven and owner_count columns using an appropriate real-world data-cleaning technique.

# %%
df['km_driven'].median()
# Out:
# 60000.0

# %%
df['km_driven'].fillna(df['km_driven'].median(),inplace=True)

# %%
df['km_driven']
# Out:
# 0        70000.0
# 1        50000.0
# 2       100000.0
# 3        46000.0
# 4       141000.0
#           ...
# 4335     60000.0
# 4336     80000.0
# 4337     83000.0
# 4338     60000.0
# 4339     40000.0
# Name: km_driven, Length: 4340, dtype: float64

# %%
df.isnull().sum()
# Out:
# vehicle_uid            0
# name                   0
# year                   0
# selling_price          0
# km_driven              0
# fuel                 435
# seller_type            0
# transmission         434
# owner                  0
# car_record_id          0
# car_age                0
# price_category       434
# km_category          434
# owner_count          434
# fuel_transmission      0
# brand                  0
# price_per_km           0
# is_diesel              0
# dtype: int64

# %%
df['owner_count'].mode()
# Out:
# 0    0.0
# Name: owner_count, dtype: float64

# %%
df['owner_count'].fillna(df['owner_count'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# vehicle_uid          0
# name                 0
# year                 0
# selling_price        0
# km_driven            0
# fuel                 0
# seller_type          0
# transmission         0
# owner                0
# car_record_id        0
# car_age              0
# price_category       0
# km_category          0
# owner_count          0
# fuel_transmission    0
# brand                0
# price_per_km         0
# is_diesel            0
# dtype: int64

# %% [markdown]
# # •  For the km_category column, 50% of the missing values should be filled with the most frequently occurring category.

# %%
df['km_category'].mode()
# Out:
# 0    Medium
# Name: km_category, dtype: object

# %%
df['km_category'].mode()
# Out:
# 0    Medium
# Name: km_category, dtype: object

# %%
df['km_category'].fillna(df['km_category'].mode()[0],limit=217,inplace=True)

# %%
df['km_category'].isnull().sum()
# Out:
# np.int64(216)

# %% [markdown]
# # The remaining 50% of missing values should be filled with the value "High".

# %%
df['km_category'].fillna('High',inplace=True)

# %%
df['km_category']
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3       Medium
# 4         High
#          ...
# 4335      High
# 4336      High
# 4337      High
# 4338      High
# 4339    Medium
# Name: km_category, Length: 4340, dtype: object

# %% [markdown]
# # •  Fill missing values in the price_category column using the most frequently occurring category in the dataset.

# %%
df['price_category'].mode()
# Out:
# 0    Low
# Name: price_category, dtype: object

# %%
df['price_category'].fillna(df['price_category'].mode()[0],inplace=True)

# %%
df['price_category']
# Out:
# 0        Low
# 1        Low
# 2        Low
# 3        Low
# 4        Low
#         ...
# 4335     Mid
# 4336     Mid
# 4337     Low
# 4338    High
# 4339     Low
# Name: price_category, Length: 4340, dtype: object

# %% [markdown]
# # For the fuel column, distribute all missing values equally among the existing unique fuel types.

# %%
df.columns
# Out:
# Index(['vehicle_uid', 'name', 'year', 'selling_price', 'km_driven', 'fuel',
#        'seller_type', 'transmission', 'owner', 'car_record_id', 'car_age',
#        'price_category', 'km_category', 'owner_count', 'fuel_transmission',
#        'brand', 'price_per_km', 'is_diesel'],
#       dtype='object')

# %%
df['transmission'].unique()
# Out:
# array(['Manual', nan, 'Automatic'], dtype=object)

# %%
df['transmission'].fillna('unknown',inplace=True)

# %%
df['transmission']
# Out:
# 0        Manual
# 1        Manual
# 2        Manual
# 3        Manual
# 4        Manual
#          ...
# 4335     Manual
# 4336    unknown
# 4337     Manual
# 4338     Manual
# 4339     Manual
# Name: transmission, Length: 4340, dtype: object

# %%
df.isnull().sum()
# Out:
# vehicle_uid            0
# name                   0
# year                   0
# selling_price          0
# km_driven              0
# fuel                 435
# seller_type            0
# transmission           0
# owner                  0
# car_record_id          0
# car_age                0
# price_category         0
# km_category            0
# owner_count          434
# fuel_transmission      0
# brand                  0
# price_per_km           0
# is_diesel              0
# dtype: int64

# %% [markdown]
# # For the fuel column, distribute all missing values equally among the existing unique fuel types.

# %%
df['fuel'].unique()
# Out:
# array(['Petrol', nan, 'Diesel', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
df['fuel'].isnull().sum()
# Out:
# np.int64(435)

# %%
435/5
# Out:
# 87.0

# %%
df['fuel'].fillna('Petrol',limit=87,inplace=True)

# %%
df['fuel'].fillna('Diesel',limit=87,inplace=True)

# %%
df['fuel'].fillna('CNG',limit=87,inplace=True)

# %%
df['fuel'].fillna('LPG',limit=87,inplace=True)

# %%
df['fuel'].fillna('Electric',limit=87,inplace=True)

# %%
df.isnull().sum()
# Out:
# vehicle_uid            0
# name                   0
# year                   0
# selling_price          0
# km_driven              0
# fuel                   0
# seller_type            0
# transmission           0
# owner                  0
# car_record_id          0
# car_age                0
# price_category         0
# km_category            0
# owner_count          434
# fuel_transmission      0
# brand                  0
# price_per_km           0
# is_diesel              0
# dtype: int64

# %%
df.to_csv("Car Dataset Cleaned.csv",index=False)

# %%
pwd
# Out:
# 'C:\\Users\\Admin\\Data Analyst Project'
